# %%
from dolfin import *

# %%
mesh = UnitCubeMesh(8,8,8)

# %%
mesh
# Out:
# <dolfin.cpp.mesh.UnitCubeMesh; proxy of <Swig Object of type 'std::shared_ptr< dolfin::UnitCubeMesh > *' at 0x10a612ab0> >

# %%
dir(mesh)
# Out:
# ['__class__',
#  '__cppinit__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  '_cell_orientations',
#  '_cells',
#  '_child',
#  '_coordinates',
#  '_debug',
#  '_leaf_node',
#  '_parent',
#  '_repr_html_',
#  '_repr_svg_',
#  '_root_node',
#  'bounding_box_tree',
#  'cell_orientations',
#  'cells',
#  'child',
#  'clean',
#  'clear_child',
#  'color',
#  'coordinates',
#  'data',
#  'depth',
#  'domains',
#  'geometry',
#  'has_child',
#  'has_parent',
#  'hash',
#  'hmax',
#  'hmin',
#  'id',
#  'init',
#  'init_cell_orientations',
#  'label',
#  'leaf_node',
#  'mpi_comm',
#  'name',
#  'num_cells',
#  'num_edges',
#  'num_entities',
#  'num_faces',
#  'num_facets',
#  'num_vertices',
#  'order',
#  'ordered',
# ...

# %%
mesh._repr_html_()
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv="content-type" content="text/html;charset=UTF-8" />\n    <meta name="generator" content="FEniCS/DOLFIN (http://fenicsproject.org)" />\n    <title>FEniCS/DOLFIN X3DOM plot</title>\n    <script type="text/javascript" src="http://www.x3dom.org/download/x3dom.js"></script>\n    <link rel="stylesheet" type="text/css" href="http://www.x3dom.org/download/x3dom.css" />\n  </head>\n  <body>\n    <x3d showStat="false" xmlns="http://www.web3d.org/specifications/x3d-namespace" width="500.000000px" height="400.000000px">\n      <scene>\n        <shape>\n          <appearance>\n            <material diffuseColor="1.000000 1.000000 1.000000" emissiveColor="0.000000 0.000000 0.000000" specularColor="0.000000 0.000000 0.000000" ambientIntensity="0" shininess="0.5" transparency="0"></material>\n          </appearance>\n          <indexedFaceSet solid="false" colorPerVertex="false" coordIndex="0 1 10 -1 0 1 82 -1 0 9 10 -1 0 9 90 -1 0 81 82 -1 0 
# ...
